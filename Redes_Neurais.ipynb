# %% [markdown]
# <a href="https://colab.research.google.com/github/hiagomereles/Data-Science-Projects/blob/main/Redes_Neurais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exemplo de um Perceptron
# Para este exemplo, vamos criar um dataset que simula a não linearidade da operação XOR. Para isto, criaremos quatro grupos distintos de dados.

# %%
# Criando o dataset XOR

import numpy as np                          # carrega a biblioteca numpy para operações matriciais

from sklearn.preprocessing import StandardScaler  # importa o método Standard Scaler para a normalização (escalamento) dos dados
from sklearn.utils import shuffle    # metodo shuffle vai embaralhar os pontos gerados

np.random.seed(1000)   # define a seed do random para que o experimento possa ser reproduzido

nb_samples = 1000              #serão criados 1000 pontos
nsb = int(nb_samples / 4)      #divididos em 4 grupos
X = np.zeros((nb_samples, 2))  #onde aqui definimos o tamanho do conjunto X (pontos) - 1000 pontos com 2 dimensões (coordenadas)
Y = np.zeros((nb_samples, ))   #e do Y (classes conjunto roxo = 1 ou conjunto amarelo = 0)

#vamos definir a pequena variação entre os pontos de cada conjunto
#coordenada 1, -1
X[0:nsb, :] = np.random.multivariate_normal([1.0, -1.0], np.diag([0.1, 0.1]), size=nsb)
Y[0:nsb] = 0.0 # classe 0

#coordenada 1, 1
X[nsb:(2 * nsb), :] = np.random.multivariate_normal([1.0, 1.0], np.diag([0.1, 0.1]), size=nsb)
Y[nsb:(2 * nsb)] = 1.0 #classe 1

#coordenada -1, 1
X[(2 * nsb):(3 * nsb), :] = np.random.multivariate_normal([-1.0, 1.0], np.diag([0.1, 0.1]), size=nsb)
Y[(2 * nsb):(3 * nsb)] = 0.0 #classe 0

#coordenada -1, -1
X[(3 * nsb):, :] = np.random.multivariate_normal([-1.0, -1.0], np.diag([0.1, 0.1]), size=nsb)
Y[(3 * nsb):] = 1.0 #classe 1

ss = StandardScaler()
X = ss.fit_transform(X) #normaliza os dados para a escala entre 0,1

X, Y = shuffle(X, Y, random_state=1000) # embaralha os dados

# %%
#Exibindo dataset XOR
import matplotlib.pyplot as plt
plt.scatter(X[:, 0], X[:, 1], c=Y)
plt.show()

# %% [markdown]
# ###Vamos verificar a acurácia usando um perceptron?

# %%
import numpy as np # carrega o numpy

from multiprocessing import cpu_count  #cpu_count define quantos núcles tem o computador - para usar paralelismo durante a execução do algoritmo

from sklearn.linear_model import Perceptron  #importa o modelo perceptron
from sklearn.model_selection import cross_val_score #utiliza o método cross validation para indicar a acurácia média do modelo

pc = Perceptron(penalty='l2', alpha=0.1, max_iter=1000, n_jobs=cpu_count(), random_state=1000) # carrega o perceptron
print(np.mean(cross_val_score(pc, X, Y, cv=10))) # exibe o a acuracia média encontrada pelo modelo
# Out:
# 0.5039999999999999

# %% [markdown]
# ###Como o perceptron separa as regiões?

# %%
#Funções para plotar a superficie (regiões)
#para demonstrar separação pelo modelo criado

import numpy as np
import matplotlib.pyplot as plt

def make_meshgrid(x, y, h=.02):
    #define a grade para as coordenadas do gráfico
    x_min, x_max = x.min() - 1, x.max() + 1
    y_min, y_max = y.min() - 1, y.max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    return xx, yy

def plot_contours(ax, clf, xx, yy, **params):
    #executa a classificação usando o modelo carregado em clf
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    out = ax.contourf(xx, yy, Z, **params)
    return out

def plot_model(clf):
    fig, ax = plt.subplots()
    # titulo do gráfico
    title = ('Superfície de Decisão')
    # configura as cooredenadas para plotar o gráfico
    X0, X1 = X[:, 0], X[:, 1]
    xx, yy = make_meshgrid(X0, X1)

    #chama a funcao pra definir os valores do modelo
    plot_contours(ax, clf, xx, yy, cmap=plt.cm.coolwarm, alpha=0.8)
    ax.scatter(X0, X1, c=Y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
    ax.set_title(title)
    plt.show()

# %%
pc.fit(X, Y) # realiza o aprendizado do modelo carregado em pc
plot_model(pc) # as funções acima para executar a classificação e exibir a linha de separaçao dos resultados

# %% [markdown]
# ###MLP - Multilayer Perceptrons

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

model = Sequential() # carrega um modelo feed-forward

model.add(Dense(4, input_dim=2)) #cria uma camada densa com com 4 neuronios e 2 entradas
model.add(Activation('tanh'))   #usando função de ativação tangente hiperbólica

model.add(Dense(2))  #cria uma camada densa com com 2 neuronios (que recebe as saídas da camada anterior)
model.add(Activation('softmax'))   #usando função de ativação softmax para definir qual é a classe na saída

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy']) # define a rede neural

# %%
#vamos separar o conjunto de treinamento e de testes
#30% para testes, o restante para treinamento

from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1000) # separa o conjunto de teste com 30% dos dados sorteados aleatóriamente com seed = 1000
#outros 70% são definidos no conjunto de teste

# %%
#treinamento da rede neural
#usando 100 épocas

#método fit executa o treinamento
model.fit(X_train,  #para o conjunto de teste "train" onde x_train sao os atributos
          to_categorical(Y_train, num_classes=2),  #e y_train sao as classes
          epochs=100,  #em 100 épocas
          batch_size=32, #de 32 em 32
          validation_data=(X_test, to_categorical(Y_test, num_classes=2))) # e demonstrando a acurácia de teste com o conjunto "X_test e Y_test"
# Out:
# Epoch 1/100
# 22/22 [==============================] - 4s 62ms/step - loss: 0.7343 - accuracy: 0.4957 - val_loss: 0.7073 - val_accuracy: 0.5400
# Epoch 2/100
# 22/22 [==============================] - 0s 19ms/step - loss: 0.7224 - accuracy: 0.4929 - val_loss: 0.7003 - val_accuracy: 0.5267
# Epoch 3/100
# 22/22 [==============================] - 1s 24ms/step - loss: 0.7136 - accuracy: 0.4843 - val_loss: 0.6941 - val_accuracy: 0.5200
# Epoch 4/100
# 22/22 [==============================] - 0s 15ms/step - loss: 0.7056 - accuracy: 0.4743 - val_loss: 0.6898 - val_accuracy: 0.5133
# Epoch 5/100
# 22/22 [==============================] - 1s 24ms/step - loss: 0.6999 - accuracy: 0.4600 - val_loss: 0.6862 - val_accuracy: 0.5000
# Epoch 6/100
# 22/22 [==============================] - 1s 24ms/step - loss: 0.6944 - accuracy: 0.4571 - val_loss: 0.6834 - val_accuracy: 0.4933
# Epoch 7/100
# 22/22 [==============================] - 1s 25ms/step - loss: 0.6900 - accuracy: 0.4543 - val_loss: 0.6809 - val_accuracy: 0.4800
# Epoch 8/100
# 22/22 [==============================] - 1s 34ms/step - loss: 0.6863 - accuracy: 0.4286 - val_loss: 0.6782 - val_accuracy: 0.4733
# Epoch 9/100
# 22/22 [==============================] - 1s 34ms/step - loss: 0.6829 - accuracy: 0.4143 - val_loss: 0.6760 - val_accuracy: 0.4700
# Epoch 10/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.6795 - accuracy: 0.4443 - val_loss: 0.6738 - val_accuracy: 0.5167
# Epoch 11/100
# 22/22 [==============================] - 1s 24ms/step - loss: 0.6761 - accuracy: 0.5057 - val_loss: 0.6711 - val_accuracy: 0.5833
# Epoch 12/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.6730 - accuracy: 0.5629 - val_loss: 0.6683 - val_accuracy: 0.6533
# Epoch 13/100
# 22/22 [==============================] - 0s 18ms/step - loss: 0.6695 - accuracy: 0.6414 - val_loss: 0.6647 - val_accuracy: 0.6867
# Epoch 14/100
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6654 - accuracy: 0.6600 - val_loss: 0.6608 - val_accuracy: 0.7100
# Epoch 15/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.6613 - accuracy: 0.6771 - val_loss: 0.6562 - val_accuracy: 0.7233
# Epoch 16/100
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6565 - accuracy: 0.6843 - val_loss: 0.6509 - val_accuracy: 0.7233
# Epoch 17/100
# 22/22 [==============================] - 0s 18ms/step - loss: 0.6507 - accuracy: 0.6957 - val_loss: 0.6450 - val_accuracy: 0.7433
# Epoch 18/100
# 22/22 [==============================] - 0s 18ms/step - loss: 0.6445 - accuracy: 0.7200 - val_loss: 0.6375 - val_accuracy: 0.7633
# Epoch 19/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.6376 - accuracy: 0.7529 - val_loss: 0.6305 - val_accuracy: 0.7700
# Epoch 20/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.6295 - accuracy: 0.7857 - val_loss: 0.6209 - val_accuracy: 0.7800
# Epoch 21/100
# 22/22 [==============================] - 1s 29ms/step - loss: 0.6207 - accuracy: 0.8229 - val_loss: 0.6114 - val_accuracy: 0.8333
# Epoch 22/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.6106 - accuracy: 0.8429 - val_loss: 0.6007 - val_accuracy: 0.8600
# Epoch 23/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.6000 - accuracy: 0.8514 - val_loss: 0.5889 - val_accuracy: 0.8867
# Epoch 24/100
# 22/22 [==============================] - 0s 11ms/step - loss: 0.5883 - accuracy: 0.8814 - val_loss: 0.5764 - val_accuracy: 0.9133
# Epoch 25/100
# 22/22 [==============================] - 0s 15ms/step - loss: 0.5759 - accuracy: 0.9129 - val_loss: 0.5630 - val_accuracy: 0.9333
# Epoch 26/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.5625 - accuracy: 0.9429 - val_loss: 0.5492 - val_accuracy: 0.9633
# Epoch 27/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5484 - accuracy: 0.9514 - val_loss: 0.5339 - val_accuracy: 0.9633
# Epoch 28/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.5337 - accuracy: 0.9629 - val_loss: 0.5186 - val_accuracy: 0.9767
# Epoch 29/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5183 - accuracy: 0.9671 - val_loss: 0.5030 - val_accuracy: 0.9800
# Epoch 30/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.5025 - accuracy: 0.9700 - val_loss: 0.4865 - val_accuracy: 0.9867
# Epoch 31/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.4861 - accuracy: 0.9743 - val_loss: 0.4700 - val_accuracy: 0.9867
# Epoch 32/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4693 - accuracy: 0.9786 - val_loss: 0.4532 - val_accuracy: 0.9900
# Epoch 33/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.4523 - accuracy: 0.9871 - val_loss: 0.4362 - val_accuracy: 0.9933
# Epoch 34/100
# 22/22 [==============================] - 0s 16ms/step - loss: 0.4349 - accuracy: 0.9886 - val_loss: 0.4193 - val_accuracy: 0.9933
# Epoch 35/100
# 22/22 [==============================] - 0s 15ms/step - loss: 0.4177 - accuracy: 0.9886 - val_loss: 0.4024 - val_accuracy: 0.9933
# Epoch 36/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4003 - accuracy: 0.9900 - val_loss: 0.3852 - val_accuracy: 0.9933
# Epoch 37/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3831 - accuracy: 0.9900 - val_loss: 0.3688 - val_accuracy: 0.9967
# Epoch 38/100
# 22/22 [==============================] - 0s 17ms/step - loss: 0.3661 - accuracy: 0.9914 - val_loss: 0.3523 - val_accuracy: 0.9967
# Epoch 39/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3495 - accuracy: 0.9914 - val_loss: 0.3362 - val_accuracy: 0.9967
# Epoch 40/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.3335 - accuracy: 0.9914 - val_loss: 0.3208 - val_accuracy: 0.9967
# Epoch 41/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3179 - accuracy: 0.9914 - val_loss: 0.3060 - val_accuracy: 0.9967
# Epoch 42/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3030 - accuracy: 0.9929 - val_loss: 0.2914 - val_accuracy: 0.9967
# Epoch 43/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.2888 - accuracy: 0.9943 - val_loss: 0.2781 - val_accuracy: 0.9967
# Epoch 44/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.2753 - accuracy: 0.9957 - val_loss: 0.2649 - val_accuracy: 0.9967
# Epoch 45/100
# 22/22 [==============================] - 0s 16ms/step - loss: 0.2625 - accuracy: 0.9957 - val_loss: 0.2528 - val_accuracy: 0.9967
# Epoch 46/100
# 22/22 [==============================] - 1s 24ms/step - loss: 0.2504 - accuracy: 0.9957 - val_loss: 0.2413 - val_accuracy: 0.9967
# Epoch 47/100
# 22/22 [==============================] - 0s 20ms/step - loss: 0.2390 - accuracy: 0.9957 - val_loss: 0.2301 - val_accuracy: 0.9967
# Epoch 48/100
# 22/22 [==============================] - 0s 19ms/step - loss: 0.2283 - accuracy: 0.9957 - val_loss: 0.2202 - val_accuracy: 0.9967
# Epoch 49/100
# 22/22 [==============================] - 0s 17ms/step - loss: 0.2182 - accuracy: 0.9957 - val_loss: 0.2103 - val_accuracy: 0.9967
# Epoch 50/100
# 22/22 [==============================] - 0s 19ms/step - loss: 0.2087 - accuracy: 0.9957 - val_loss: 0.2014 - val_accuracy: 0.9967
# Epoch 51/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.1998 - accuracy: 0.9957 - val_loss: 0.1928 - val_accuracy: 0.9967
# Epoch 52/100
# 22/22 [==============================] - 0s 15ms/step - loss: 0.1914 - accuracy: 0.9957 - val_loss: 0.1847 - val_accuracy: 1.0000
# Epoch 53/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.1835 - accuracy: 0.9957 - val_loss: 0.1770 - val_accuracy: 1.0000
# Epoch 54/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1762 - accuracy: 0.9971 - val_loss: 0.1701 - val_accuracy: 1.0000
# Epoch 55/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.1692 - accuracy: 0.9971 - val_loss: 0.1631 - val_accuracy: 1.0000
# Epoch 56/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.1627 - accuracy: 0.9971 - val_loss: 0.1569 - val_accuracy: 1.0000
# Epoch 57/100
# 22/22 [==============================] - 0s 17ms/step - loss: 0.1565 - accuracy: 0.9971 - val_loss: 0.1511 - val_accuracy: 1.0000
# Epoch 58/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1506 - accuracy: 0.9971 - val_loss: 0.1455 - val_accuracy: 1.0000
# Epoch 59/100
# 22/22 [==============================] - 0s 16ms/step - loss: 0.1452 - accuracy: 0.9971 - val_loss: 0.1403 - val_accuracy: 1.0000
# Epoch 60/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1400 - accuracy: 0.9971 - val_loss: 0.1352 - val_accuracy: 1.0000
# Epoch 61/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.1351 - accuracy: 0.9986 - val_loss: 0.1305 - val_accuracy: 1.0000
# Epoch 62/100
# 22/22 [==============================] - 0s 23ms/step - loss: 0.1305 - accuracy: 0.9986 - val_loss: 0.1258 - val_accuracy: 1.0000
# Epoch 63/100
# 22/22 [==============================] - 1s 31ms/step - loss: 0.1261 - accuracy: 0.9986 - val_loss: 0.1216 - val_accuracy: 1.0000
# Epoch 64/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1220 - accuracy: 0.9986 - val_loss: 0.1176 - val_accuracy: 1.0000
# Epoch 65/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1180 - accuracy: 0.9986 - val_loss: 0.1138 - val_accuracy: 1.0000
# Epoch 66/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1143 - accuracy: 0.9986 - val_loss: 0.1102 - val_accuracy: 1.0000
# Epoch 67/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1108 - accuracy: 0.9986 - val_loss: 0.1067 - val_accuracy: 1.0000
# Epoch 68/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1074 - accuracy: 0.9986 - val_loss: 0.1034 - val_accuracy: 1.0000
# Epoch 69/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1042 - accuracy: 0.9986 - val_loss: 0.1004 - val_accuracy: 1.0000
# Epoch 70/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1012 - accuracy: 0.9986 - val_loss: 0.0975 - val_accuracy: 1.0000
# Epoch 71/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0983 - accuracy: 0.9986 - val_loss: 0.0946 - val_accuracy: 1.0000
# Epoch 72/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0955 - accuracy: 0.9986 - val_loss: 0.0920 - val_accuracy: 1.0000
# Epoch 73/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0929 - accuracy: 0.9986 - val_loss: 0.0895 - val_accuracy: 1.0000
# Epoch 74/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0904 - accuracy: 0.9986 - val_loss: 0.0870 - val_accuracy: 1.0000
# Epoch 75/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0880 - accuracy: 0.9986 - val_loss: 0.0847 - val_accuracy: 1.0000
# Epoch 76/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0857 - accuracy: 0.9986 - val_loss: 0.0824 - val_accuracy: 1.0000
# Epoch 77/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0834 - accuracy: 0.9986 - val_loss: 0.0802 - val_accuracy: 1.0000
# Epoch 78/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0813 - accuracy: 0.9986 - val_loss: 0.0783 - val_accuracy: 1.0000
# Epoch 79/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0793 - accuracy: 0.9986 - val_loss: 0.0762 - val_accuracy: 1.0000
# Epoch 80/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0774 - accuracy: 0.9986 - val_loss: 0.0744 - val_accuracy: 1.0000
# Epoch 81/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0755 - accuracy: 0.9986 - val_loss: 0.0725 - val_accuracy: 1.0000
# Epoch 82/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0737 - accuracy: 0.9986 - val_loss: 0.0708 - val_accuracy: 1.0000
# Epoch 83/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0720 - accuracy: 0.9986 - val_loss: 0.0692 - val_accuracy: 1.0000
# Epoch 84/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0704 - accuracy: 1.0000 - val_loss: 0.0675 - val_accuracy: 1.0000
# Epoch 85/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0688 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 1.0000
# Epoch 86/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0673 - accuracy: 1.0000 - val_loss: 0.0645 - val_accuracy: 1.0000
# Epoch 87/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0658 - accuracy: 1.0000 - val_loss: 0.0630 - val_accuracy: 1.0000
# Epoch 88/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0644 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 1.0000
# Epoch 89/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0631 - accuracy: 1.0000 - val_loss: 0.0603 - val_accuracy: 1.0000
# Epoch 90/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0617 - accuracy: 1.0000 - val_loss: 0.0592 - val_accuracy: 1.0000
# Epoch 91/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0605 - accuracy: 1.0000 - val_loss: 0.0578 - val_accuracy: 1.0000
# Epoch 92/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0593 - accuracy: 1.0000 - val_loss: 0.0568 - val_accuracy: 1.0000
# Epoch 93/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0581 - accuracy: 1.0000 - val_loss: 0.0556 - val_accuracy: 1.0000
# Epoch 94/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0569 - accuracy: 1.0000 - val_loss: 0.0544 - val_accuracy: 1.0000
# Epoch 95/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0558 - accuracy: 1.0000 - val_loss: 0.0534 - val_accuracy: 1.0000
# Epoch 96/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0548 - accuracy: 1.0000 - val_loss: 0.0523 - val_accuracy: 1.0000
# Epoch 97/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0537 - accuracy: 1.0000 - val_loss: 0.0514 - val_accuracy: 1.0000
# Epoch 98/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0528 - accuracy: 1.0000 - val_loss: 0.0503 - val_accuracy: 1.0000
# Epoch 99/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 0.0495 - val_accuracy: 1.0000
# Epoch 100/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0508 - accuracy: 1.0000 - val_loss: 0.0485 - val_accuracy: 1.0000

# %%
#verificação(predição) usando a base de teste
#qual seria a resposta da rede treinada se ela classificar os pontos que estao no conjunto de testes?

Y_eval_mlp = np.argmax(model.predict(X_test), axis=1) #retorna as classes definidas pelo modelo
# Out:
# 10/10 [==============================] - 0s 2ms/step

# %%
#plotando os resultados
import matplotlib.pyplot as plt
plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_eval_mlp) # exibe pontos para coordenadas em X_Test definindo as cores a partir dos dados em Y_eval_mlp
plt.show() #exibe gráfico

# %% [markdown]
# ###Superficie usando o modelo atual com tanh

# %%
#para verificarmos os limites entre os conjuntos de classificação
#vamos criar um conjunto com muitos pontos gerados aleatóriamente
#e usar o modelo para definir qual seria sua classe

import numpy as np

Xm = np.linspace(-2.0, 2.0, 1000) # cria 1000 pontos para a coordenada X
Ym = np.linspace(-2.0, 2.0, 1000) # cria 1000 pontos para a coordenada Y
Xmg, Ymg = np.meshgrid(Xm, Ym)  #retorna as coordenadas da grade 2-D com base nas coordenadas contidas nos vetores x e y
X_eval = np.vstack([Xmg.ravel(), Ymg.ravel()]).T #cria o conjunto de entradas para as coordenadas geradas

Y_eval_mlp = np.argmax(model.predict(X_eval), axis=1) # usa o modelo carregado em model para realizar a classificação
# Out:
# 31250/31250 [==============================] - 53s 2ms/step

# %%
#plotando os resultados
import matplotlib.pyplot as plt
plt.scatter(X_eval[:, 0], X_eval[:, 1], c=Y_eval_mlp) # exibe pontos para coordenadas em X_Test definindo as cores a partir dos dados em Y_eval_mlp
plt.show() #exibe gráfico

# %% [markdown]
# ###E se criarmos um modelo usando função de ativação Relu?

# %%
#para isto, vamos reproduzir a mesma rede neural anterior
#mas mudando a função de ativação

model = Sequential() # carrega um modelo feed-forward

model.add(Dense(4, input_dim=2)) #cria uma camada densa com com 4 neuronios e 2 entradas
model.add(Activation('relu'))   #usando função de ativação relu

model.add(Dense(2))  #cria uma camada densa com com 2 neuronios (que recebe as saídas da camada anterior)
model.add(Activation('softmax'))   #usando função de ativação softmax para definir qual é a classe na saída

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy']) # define a rede neural

# %%
#vamos separar o conjunto de treinamento e de testes
#30% para testes, o restante para treinamento

from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1000) # separa o conjunto de teste com 30% dos dados sorteados aleatóriamente com seed = 1000
#outros 70% são definidos no conjunto de teste

#treinamento da rede neural
#usando 100 épocas

#método fit executa o treinamento
model.fit(X_train,  #para o conjunto de teste "train" onde x_train sao os atributos
          to_categorical(Y_train, num_classes=2),  #e y_train sao as classes
          epochs=100,  #em 100 épocas
          batch_size=32, #de 32 em 32
          validation_data=(X_test, to_categorical(Y_test, num_classes=2))) # e demonstrando a acurácia de teste com o conjunto "X_test e Y_test"
# Out:
# Epoch 1/100
# 22/22 [==============================] - 1s 13ms/step - loss: 0.4988 - accuracy: 0.7500 - val_loss: 0.5016 - val_accuracy: 0.8000
# Epoch 2/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4867 - accuracy: 0.7914 - val_loss: 0.4904 - val_accuracy: 0.8367
# Epoch 3/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4745 - accuracy: 0.8286 - val_loss: 0.4789 - val_accuracy: 0.8600
# Epoch 4/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.4617 - accuracy: 0.8543 - val_loss: 0.4669 - val_accuracy: 0.8733
# Epoch 5/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4487 - accuracy: 0.8757 - val_loss: 0.4542 - val_accuracy: 0.8833
# Epoch 6/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4352 - accuracy: 0.8929 - val_loss: 0.4413 - val_accuracy: 0.9000
# Epoch 7/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.4213 - accuracy: 0.9100 - val_loss: 0.4282 - val_accuracy: 0.9100
# Epoch 8/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4072 - accuracy: 0.9243 - val_loss: 0.4152 - val_accuracy: 0.9100
# Epoch 9/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3930 - accuracy: 0.9357 - val_loss: 0.4013 - val_accuracy: 0.9200
# Epoch 10/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3789 - accuracy: 0.9457 - val_loss: 0.3882 - val_accuracy: 0.9300
# Epoch 11/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3647 - accuracy: 0.9529 - val_loss: 0.3747 - val_accuracy: 0.9333
# Epoch 12/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3509 - accuracy: 0.9543 - val_loss: 0.3615 - val_accuracy: 0.9400
# Epoch 13/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3374 - accuracy: 0.9614 - val_loss: 0.3491 - val_accuracy: 0.9400
# Epoch 14/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3243 - accuracy: 0.9671 - val_loss: 0.3368 - val_accuracy: 0.9433
# Epoch 15/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3118 - accuracy: 0.9700 - val_loss: 0.3247 - val_accuracy: 0.9533
# Epoch 16/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2996 - accuracy: 0.9700 - val_loss: 0.3135 - val_accuracy: 0.9567
# Epoch 17/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2882 - accuracy: 0.9757 - val_loss: 0.3028 - val_accuracy: 0.9600
# Epoch 18/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2772 - accuracy: 0.9771 - val_loss: 0.2919 - val_accuracy: 0.9667
# Epoch 19/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2666 - accuracy: 0.9757 - val_loss: 0.2823 - val_accuracy: 0.9667
# Epoch 20/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2567 - accuracy: 0.9771 - val_loss: 0.2725 - val_accuracy: 0.9667
# Epoch 21/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.2471 - accuracy: 0.9814 - val_loss: 0.2636 - val_accuracy: 0.9700
# Epoch 22/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.2381 - accuracy: 0.9829 - val_loss: 0.2546 - val_accuracy: 0.9700
# Epoch 23/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2296 - accuracy: 0.9829 - val_loss: 0.2464 - val_accuracy: 0.9700
# Epoch 24/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2215 - accuracy: 0.9843 - val_loss: 0.2386 - val_accuracy: 0.9733
# Epoch 25/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2139 - accuracy: 0.9843 - val_loss: 0.2313 - val_accuracy: 0.9800
# Epoch 26/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2066 - accuracy: 0.9843 - val_loss: 0.2238 - val_accuracy: 0.9800
# Epoch 27/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1996 - accuracy: 0.9843 - val_loss: 0.2170 - val_accuracy: 0.9800
# Epoch 28/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1931 - accuracy: 0.9843 - val_loss: 0.2105 - val_accuracy: 0.9833
# Epoch 29/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1869 - accuracy: 0.9857 - val_loss: 0.2039 - val_accuracy: 0.9833
# Epoch 30/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1809 - accuracy: 0.9857 - val_loss: 0.1978 - val_accuracy: 0.9833
# Epoch 31/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1752 - accuracy: 0.9871 - val_loss: 0.1920 - val_accuracy: 0.9833
# Epoch 32/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1698 - accuracy: 0.9871 - val_loss: 0.1862 - val_accuracy: 0.9833
# Epoch 33/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.1646 - accuracy: 0.9857 - val_loss: 0.1810 - val_accuracy: 0.9833
# Epoch 34/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1597 - accuracy: 0.9857 - val_loss: 0.1757 - val_accuracy: 0.9833
# Epoch 35/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1550 - accuracy: 0.9857 - val_loss: 0.1706 - val_accuracy: 0.9833
# Epoch 36/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.1505 - accuracy: 0.9857 - val_loss: 0.1657 - val_accuracy: 0.9833
# Epoch 37/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.1461 - accuracy: 0.9871 - val_loss: 0.1613 - val_accuracy: 0.9833
# Epoch 38/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.1420 - accuracy: 0.9886 - val_loss: 0.1569 - val_accuracy: 0.9867
# Epoch 39/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.1381 - accuracy: 0.9900 - val_loss: 0.1526 - val_accuracy: 0.9867
# Epoch 40/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.1343 - accuracy: 0.9900 - val_loss: 0.1487 - val_accuracy: 0.9867
# Epoch 41/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1307 - accuracy: 0.9900 - val_loss: 0.1444 - val_accuracy: 0.9867
# Epoch 42/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.1272 - accuracy: 0.9900 - val_loss: 0.1407 - val_accuracy: 0.9867
# Epoch 43/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.1239 - accuracy: 0.9914 - val_loss: 0.1370 - val_accuracy: 0.9867
# Epoch 44/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1206 - accuracy: 0.9914 - val_loss: 0.1336 - val_accuracy: 0.9867
# Epoch 45/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1176 - accuracy: 0.9914 - val_loss: 0.1304 - val_accuracy: 0.9867
# Epoch 46/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1146 - accuracy: 0.9929 - val_loss: 0.1270 - val_accuracy: 0.9867
# Epoch 47/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1118 - accuracy: 0.9943 - val_loss: 0.1238 - val_accuracy: 0.9867
# Epoch 48/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1090 - accuracy: 0.9943 - val_loss: 0.1208 - val_accuracy: 0.9867
# Epoch 49/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1064 - accuracy: 0.9943 - val_loss: 0.1180 - val_accuracy: 0.9867
# Epoch 50/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1038 - accuracy: 0.9943 - val_loss: 0.1153 - val_accuracy: 0.9867
# Epoch 51/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1015 - accuracy: 0.9943 - val_loss: 0.1126 - val_accuracy: 0.9867
# Epoch 52/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0991 - accuracy: 0.9957 - val_loss: 0.1097 - val_accuracy: 0.9900
# Epoch 53/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0968 - accuracy: 0.9957 - val_loss: 0.1073 - val_accuracy: 0.9933
# Epoch 54/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0946 - accuracy: 0.9957 - val_loss: 0.1047 - val_accuracy: 0.9933
# Epoch 55/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0925 - accuracy: 0.9957 - val_loss: 0.1025 - val_accuracy: 0.9933
# Epoch 56/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0905 - accuracy: 0.9957 - val_loss: 0.1001 - val_accuracy: 0.9933
# Epoch 57/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0885 - accuracy: 0.9957 - val_loss: 0.0979 - val_accuracy: 0.9933
# Epoch 58/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0866 - accuracy: 0.9957 - val_loss: 0.0960 - val_accuracy: 0.9933
# Epoch 59/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0848 - accuracy: 0.9957 - val_loss: 0.0939 - val_accuracy: 0.9933
# Epoch 60/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0830 - accuracy: 0.9957 - val_loss: 0.0918 - val_accuracy: 0.9933
# Epoch 61/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0813 - accuracy: 0.9957 - val_loss: 0.0900 - val_accuracy: 0.9933
# Epoch 62/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0797 - accuracy: 0.9957 - val_loss: 0.0881 - val_accuracy: 0.9933
# Epoch 63/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0781 - accuracy: 0.9957 - val_loss: 0.0865 - val_accuracy: 0.9933
# Epoch 64/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0766 - accuracy: 0.9957 - val_loss: 0.0846 - val_accuracy: 0.9933
# Epoch 65/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0750 - accuracy: 0.9957 - val_loss: 0.0831 - val_accuracy: 0.9933
# Epoch 66/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0736 - accuracy: 0.9957 - val_loss: 0.0814 - val_accuracy: 0.9933
# Epoch 67/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0722 - accuracy: 0.9957 - val_loss: 0.0798 - val_accuracy: 0.9933
# Epoch 68/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0708 - accuracy: 0.9957 - val_loss: 0.0782 - val_accuracy: 0.9933
# Epoch 69/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0696 - accuracy: 0.9957 - val_loss: 0.0766 - val_accuracy: 0.9933
# Epoch 70/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0683 - accuracy: 0.9957 - val_loss: 0.0752 - val_accuracy: 0.9933
# Epoch 71/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0670 - accuracy: 0.9957 - val_loss: 0.0739 - val_accuracy: 0.9933
# Epoch 72/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0658 - accuracy: 0.9957 - val_loss: 0.0724 - val_accuracy: 0.9933
# Epoch 73/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0646 - accuracy: 0.9957 - val_loss: 0.0710 - val_accuracy: 0.9933
# Epoch 74/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0635 - accuracy: 0.9957 - val_loss: 0.0698 - val_accuracy: 0.9933
# Epoch 75/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0624 - accuracy: 0.9957 - val_loss: 0.0685 - val_accuracy: 0.9933
# Epoch 76/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0613 - accuracy: 0.9957 - val_loss: 0.0673 - val_accuracy: 0.9933
# Epoch 77/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0602 - accuracy: 0.9957 - val_loss: 0.0661 - val_accuracy: 0.9933
# Epoch 78/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0592 - accuracy: 0.9957 - val_loss: 0.0650 - val_accuracy: 0.9933
# Epoch 79/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0582 - accuracy: 0.9957 - val_loss: 0.0639 - val_accuracy: 0.9933
# Epoch 80/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0573 - accuracy: 0.9957 - val_loss: 0.0626 - val_accuracy: 0.9933
# Epoch 81/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0563 - accuracy: 0.9957 - val_loss: 0.0617 - val_accuracy: 0.9933
# Epoch 82/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0554 - accuracy: 0.9957 - val_loss: 0.0606 - val_accuracy: 0.9933
# Epoch 83/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0545 - accuracy: 0.9971 - val_loss: 0.0595 - val_accuracy: 0.9933
# Epoch 84/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0536 - accuracy: 0.9971 - val_loss: 0.0586 - val_accuracy: 0.9933
# Epoch 85/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0528 - accuracy: 0.9971 - val_loss: 0.0576 - val_accuracy: 0.9933
# Epoch 86/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0520 - accuracy: 0.9971 - val_loss: 0.0568 - val_accuracy: 0.9933
# Epoch 87/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0512 - accuracy: 0.9971 - val_loss: 0.0559 - val_accuracy: 0.9933
# Epoch 88/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0504 - accuracy: 0.9971 - val_loss: 0.0549 - val_accuracy: 0.9933
# Epoch 89/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0496 - accuracy: 0.9971 - val_loss: 0.0541 - val_accuracy: 0.9933
# Epoch 90/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0489 - accuracy: 0.9971 - val_loss: 0.0532 - val_accuracy: 0.9933
# Epoch 91/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0482 - accuracy: 0.9971 - val_loss: 0.0524 - val_accuracy: 0.9933
# Epoch 92/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0475 - accuracy: 0.9971 - val_loss: 0.0515 - val_accuracy: 0.9967
# Epoch 93/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0468 - accuracy: 0.9986 - val_loss: 0.0508 - val_accuracy: 0.9967
# Epoch 94/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0461 - accuracy: 0.9986 - val_loss: 0.0501 - val_accuracy: 0.9933
# Epoch 95/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0454 - accuracy: 0.9986 - val_loss: 0.0493 - val_accuracy: 0.9967
# Epoch 96/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0447 - accuracy: 0.9986 - val_loss: 0.0486 - val_accuracy: 0.9967
# Epoch 97/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0441 - accuracy: 0.9986 - val_loss: 0.0479 - val_accuracy: 0.9967
# Epoch 98/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0435 - accuracy: 0.9986 - val_loss: 0.0470 - val_accuracy: 0.9967
# Epoch 99/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0429 - accuracy: 0.9986 - val_loss: 0.0465 - val_accuracy: 0.9967
# Epoch 100/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0423 - accuracy: 0.9986 - val_loss: 0.0458 - val_accuracy: 0.9967

# %%
#verificação(predição) usando a base de teste
#qual seria a resposta da rede treinada se ela classificar os pontos que estao no conjunto de testes?

Y_eval_mlp = np.argmax(model.predict(X_test), axis=1) #retorna as classes definidas pelo modelo
# Out:
# 10/10 [==============================] - 0s 2ms/step

# %%
#plotando os resultados
import matplotlib.pyplot as plt
plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_eval_mlp) # exibe pontos para coordenadas em X_Test definindo as cores a partir dos dados em Y_eval_mlp
plt.show() #exibe gráfico

# %%
#para verificarmos os limites entre os conjuntos de classificação
#vamos criar um conjunto com muitos pontos gerados aleatóriamente
#e usar o modelo para definir qual seria sua classe

import numpy as np

Xm = np.linspace(-2.0, 2.0, 1000) # cria 1000 pontos para a coordenada X
Ym = np.linspace(-2.0, 2.0, 1000) # cria 1000 pontos para a coordenada Y
Xmg, Ymg = np.meshgrid(Xm, Ym)  #retorna as coordenadas da grade 2-D com base nas coordenadas contidas nos vetores x e y
X_eval = np.vstack([Xmg.ravel(), Ymg.ravel()]).T #cria o conjunto de entradas para as coordenadas geradas

Y_eval_mlp = np.argmax(model.predict(X_eval), axis=1) # usa o modelo carregado em model para realizar a classificação
# Out:
# 31250/31250 [==============================] - 52s 2ms/step

# %%
#plotando os resultados
import matplotlib.pyplot as plt
plt.scatter(X_eval[:, 0], X_eval[:, 1], c=Y_eval_mlp) # exibe pontos para coordenadas em X_Test definindo as cores a partir dos dados em Y_eval_mlp
plt.show() #exibe gráfico
